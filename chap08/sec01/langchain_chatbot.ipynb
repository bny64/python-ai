# %%
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.messages import HumanMessage

model.invoke([HumanMessage(content="안녕? 나는 이성용이야.")])
# Out:
# AIMessage(content='안녕하세요, 이성용 님! 만나서 반갑습니다.\n\n저는 인공지능 챗봇입니다. 무엇을 도와드릴까요?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f79b9-78ba-7b43-9739-11a8aaa168e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 308, 'total_tokens': 318, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 279}})
